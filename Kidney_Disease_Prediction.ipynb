# %%
import pandas as pd

# %%
df=pd.read_csv('kidney_disease_train.csv')

# %%
df
# Out:
#       id   age     bp     sg   al   su     rbc        pc         pcc  \
# 0    157  62.0   70.0  1.025  3.0  0.0  normal  abnormal  notpresent
# 1    109  54.0   70.0    NaN  NaN  NaN     NaN       NaN  notpresent
# 2     17  47.0   80.0    NaN  NaN  NaN     NaN       NaN  notpresent
# 3    347  43.0   60.0  1.025  0.0  0.0  normal    normal  notpresent
# 4     24  42.0  100.0  1.015  4.0  0.0  normal  abnormal  notpresent
# ..   ...   ...    ...    ...  ...  ...     ...       ...         ...
# 275   71  46.0   60.0  1.010  1.0  0.0  normal    normal  notpresent
# 276  106  50.0   90.0    NaN  NaN  NaN     NaN       NaN  notpresent
# 277  270  23.0   80.0  1.025  0.0  0.0  normal    normal  notpresent
# 278  348  38.0   80.0  1.020  0.0  0.0  normal    normal  notpresent
# 279  102  17.0   60.0  1.010  0.0  0.0     NaN    normal  notpresent
#
#              ba  ...   pcv     wc   rc  htn   dm  cad  appet   pe  ane  \
# ...

# %%
df.head()
# Out:
#     id   age     bp     sg   al   su     rbc        pc         pcc  \
# 0  157  62.0   70.0  1.025  3.0  0.0  normal  abnormal  notpresent
# 1  109  54.0   70.0    NaN  NaN  NaN     NaN       NaN  notpresent
# 2   17  47.0   80.0    NaN  NaN  NaN     NaN       NaN  notpresent
# 3  347  43.0   60.0  1.025  0.0  0.0  normal    normal  notpresent
# 4   24  42.0  100.0  1.015  4.0  0.0  normal  abnormal  notpresent
#
#            ba  ...   pcv    wc   rc  htn   dm  cad  appet  pe ane  \
# 0  notpresent  ...  39.0  7900  3.9  yes  yes   no   good  no  no
# 1  notpresent  ...   NaN   NaN  NaN   no  yes   no   good  no  no
# 2  notpresent  ...   NaN   NaN  NaN  yes   no   no   poor  no  no
# 3  notpresent  ...  43.0  7200  5.5   no   no   no   good  no  no
# 4     present  ...  39.0  8300  4.6  yes   no   no   poor  no  no
#
#   classification
# 0            ckd
# 1            ckd
# 2            ckd
# 3         notckd
# 4            ckd
#
# [5 rows x 26 columns]

# %%
df.head(10)
# Out:
#     id   age     bp     sg   al   su       rbc        pc         pcc  \
# 0  157  62.0   70.0  1.025  3.0  0.0    normal  abnormal  notpresent
# 1  109  54.0   70.0    NaN  NaN  NaN       NaN       NaN  notpresent
# 2   17  47.0   80.0    NaN  NaN  NaN       NaN       NaN  notpresent
# 3  347  43.0   60.0  1.025  0.0  0.0    normal    normal  notpresent
# 4   24  42.0  100.0  1.015  4.0  0.0    normal  abnormal  notpresent
# 5  175  60.0   50.0  1.010  0.0  0.0       NaN    normal  notpresent
# 6  351  29.0   80.0  1.020  0.0  0.0    normal    normal  notpresent
# 7  332  34.0   70.0  1.025  0.0  0.0    normal    normal  notpresent
# 8  167  34.0   70.0  1.020  0.0  0.0  abnormal    normal  notpresent
# 9  245  48.0  100.0    NaN  NaN  NaN       NaN       NaN  notpresent
#
#            ba  ...   pcv     wc   rc  htn   dm  cad  appet  pe ane  \
# 0  notpresent  ...  39.0   7900  3.9  yes  yes   no   good  no  no
# 1  notpresent  ...   NaN    NaN  NaN   no  yes   no   good  no  no
# ...

# %%
df.tail()
# Out:
#       id   age    bp     sg   al   su     rbc      pc         pcc          ba  \
# 275   71  46.0  60.0  1.010  1.0  0.0  normal  normal  notpresent  notpresent
# 276  106  50.0  90.0    NaN  NaN  NaN     NaN     NaN  notpresent  notpresent
# 277  270  23.0  80.0  1.025  0.0  0.0  normal  normal  notpresent  notpresent
# 278  348  38.0  80.0  1.020  0.0  0.0  normal  normal  notpresent  notpresent
# 279  102  17.0  60.0  1.010  0.0  0.0     NaN  normal  notpresent  notpresent
#
#      ...   pcv     wc   rc  htn   dm  cad  appet   pe  ane classification
# 275  ...  28.0  14600  3.2  yes  yes   no   good   no   no            ckd
# 276  ...  17.0   6500  NaN  yes  yes   no   good  yes  yes            ckd
# 277  ...  41.0   7200  5.0   no   no   no   good   no   no         notckd
# 278  ...  44.0   7300  6.4   no   no   no   good   no   no         notckd
# 279  ...  52.0   7000  NaN   no   no   no   good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
df.tail(20)
# Out:
#       id   age     bp     sg   al   su       rbc        pc         pcc  \
# 260  257  38.0   60.0  1.020  0.0  0.0    normal    normal  notpresent
# 261  308  43.0   80.0  1.025  0.0  0.0    normal    normal  notpresent
# 262  149  65.0   70.0  1.020  1.0  0.0  abnormal  abnormal  notpresent
# 263  130  50.0   90.0  1.010  2.0  0.0    normal  abnormal     present
# 264  151  76.0   90.0    NaN  NaN  NaN       NaN       NaN  notpresent
# 265  359  74.0   60.0  1.020  0.0  0.0    normal    normal  notpresent
# 266   99  56.0  180.0    NaN  0.0  4.0       NaN  abnormal  notpresent
# 267  372  72.0   60.0  1.020  0.0  0.0    normal    normal  notpresent
# 268   87  70.0  100.0  1.005  1.0  0.0    normal  abnormal     present
# 269  330  43.0   80.0  1.020  0.0  0.0    normal    normal  notpresent
# 270  214  68.0   80.0  1.015  0.0  0.0       NaN  abnormal  notpresent
# 271  121  54.0   60.0    NaN  3.0  NaN       NaN       NaN  notpresent
# ...

# %%
df.shape
# Out:
# (280, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              280 non-null    int64
#  1   age             275 non-null    float64
#  2   bp              271 non-null    float64
#  3   sg              244 non-null    float64
#  4   al              245 non-null    float64
#  5   su              242 non-null    float64
#  6   rbc             173 non-null    object
#  7   pc              230 non-null    object
#  8   pcc             276 non-null    object
#  9   ba              276 non-null    object
#  10  bgr             247 non-null    float64
#  11  bu              266 non-null    float64
#  12  sc              268 non-null    float64
#  13  sod             213 non-null    float64
#  14  pot             212 non-null    float64
#  15  hemo            241 non-null    float64
#  16  pcv             229 non-null    float64
# ...

# %%
df.dtypes
# Out:
# id                  int64
# age               float64
# bp                float64
# sg                float64
# al                float64
# su                float64
# rbc                object
# pc                 object
# pcc                object
# ba                 object
# bgr               float64
# bu                float64
# sc                float64
# sod               float64
# pot               float64
# hemo              float64
# pcv               float64
# wc                 object
# rc                 object
# htn                object
# dm                 object
# cad                object
# appet              object
# pe                 object
# ane                object
# classification     object
# dtype: object

# %%
df.describe()
# Out:
#                id         age          bp          sg          al          su  \
# count  280.000000  275.000000  271.000000  244.000000  245.000000  242.000000
# mean   202.928571   51.454545   76.051661    1.017439    1.024490    0.438017
# std    111.988168   17.476176   14.256289    0.005746    1.375805    1.073193
# min      1.000000    2.000000   50.000000    1.005000    0.000000    0.000000
# 25%    110.500000   42.000000   70.000000    1.010000    0.000000    0.000000
# 50%    202.000000   55.000000   70.000000    1.020000    0.000000    0.000000
# 75%    302.250000   65.000000   80.000000    1.020000    2.000000    0.000000
# max    399.000000   90.000000  180.000000    1.025000    5.000000    5.000000
#
#               bgr          bu          sc         sod         pot        hemo  \
# count  247.000000  266.000000  268.000000  213.000000  212.000000  241.000000
# mean   150.186235   56.983835    3.006157  137.255869    4.754245   12.531535
# ...
